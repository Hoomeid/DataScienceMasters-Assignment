# %% [markdown]
# ## What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %%
#Matplotlib is a powerful plotting library in Python used for creating static, animated, and interactive visualizations.
#Matplotlib is primary used to provide users with the tools and functionality to represent data graphically, making it easier to analyze and understand
#Five plots that can be plotted using Matplotlib are plots, scatter plots, bar plots, histograms, pie charts

# %% [markdown]
# ## What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
#Note: Also add title, xlabel, and ylabel to the plot.

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel('This is the X axis')
plt.ylabel('This is the Y axis')
plt.title("This is my first plot")
# Out:
# Text(0.5, 1.0, 'This is my first plot')

# %%
fig, axs = plt.subplots(2,2)
axs[0,0].plot([0, 1, 2, 3, 4, 5], [0, 100, 200, 300, 400, 500])
axs[0,1].plot([0, 1, 2, 3, 4, 5], [50, 20, 40, 20, 60, 70])
axs[1,0].plot([0, 1, 2, 3, 4, 5], [10, 20, 30, 40, 50, 60])
axs[1,1].plot([0, 1, 2, 3, 4, 5], [200, 350, 250, 550, 450, 150])

# %% [markdown]
# ## What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
#A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent. The bar plots can be plotted horizontally or vertically.

# %%
import numpy as np
company = ["Apple", "Microsoft", "Google", "AMD"]
profit = [3000, 8000, 1000, 10000]

# %%
# Vertical bar plot
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
# Horizontal bar plot
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
# Box Plot is a graphical method to visualize data distribution for gaining insights and making informed decisions. Box plot is a type of chart that depicts a group of numerical data through their quartiles.

# %%
# uses
# The dispersion or spread of data can be visualized by the minimum and maximum values which are found at the end of the whiskers.
# The Box plot gives us the idea of about the Outliers which are the points which are numerically distant from the rest of the data.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
fig, ax = plt.subplots()
ax.boxplot([box1,box2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a7ab2801d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a7ab3247d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a7a901f610>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2a7ab357d50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2a7ab356e10>,
# ...
#  'means': []}
